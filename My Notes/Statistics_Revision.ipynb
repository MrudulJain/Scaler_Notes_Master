# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import scipy
from scipy import stats

# %%
scipy.__version__
# Out:
# '1.11.1'

# %%
np.linspace(-4, 4, 3)
# Out:
# array([-4.,  0.,  4.])

# %%
np.arange(-4, 5, 4)
# Out:
# array([-4,  0,  4])

# %%
# mean = 20, sigma = 0.6
# mean = 70, sigma = 4

mu = 20
sigma = 0.6

# Create x values (extending to ±4 standard deviations from the mean)
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
pdf = stats.norm.pdf(x, mean, std_dev)

# Manually calculating the pdf function for x = mean + 4*std_dev
x1 = mean + 4*std_dev
coefficient = 1 / (sigma * np.sqrt(2 * np.pi))
exponent = np.exp(-1*((x1 - mu) ** 2) / (2 * sigma ** 2))
print(coefficient * exponent)


print(pdf[:5])
print(min(pdf))
# Out:
# 0.00022305037627481092
# [0.00022305 0.0002303  0.00023778 0.00024548 0.00025341]
# 0.00022305037627481095

# %%
# Plot the PDF curve
plt.plot(x, pdf, 'b-', linewidth=2, label=f'Normal Distribution (μ={mean}, σ={std_dev})')

# Fill the area under the curve
plt.fill_between(x, pdf, alpha=0.3, color='blue')

# Generate random samples from this distribution for a histogram overlay
samples = np.random.normal(mean, std_dev, 1000)
sns.histplot(samples, stat='density', kde=False, alpha=0.4, color='green', bins=30, label='Samples')

# Add vertical line for the mean
plt.axvline(mean, color='red', linestyle='--', alpha=0.7, label='Mean')

# Add annotations for mean and standard deviation ranges
plt.annotate(f'μ = {mean}', xy=(mean, 0.05), xytext=(mean+0.1, 0.1),
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5), fontsize=12)

# Label for ±1 standard deviation
plt.annotate('68% of data', xy=(mean, 0.3), xytext=(mean, 0.4),
            ha='center', fontsize=12)

# Add arrows for ±1 standard deviation
plt.annotate('', xy=(mean - std_dev, 0.3), xytext=(mean + std_dev, 0.3),
            arrowprops=dict(arrowstyle='<->', color='black'))

# Add title and labels
plt.title('Normal Distribution (Bell Curve)', fontsize=16)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Probability Density', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()

# Tighten the layout and display the plot
plt.tight_layout()
plt.show()
