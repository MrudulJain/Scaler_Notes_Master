# %%
import pandas as pd
#unlike numpy, pandas can work with multiple data-types
import numpy as np

# %%
df = pd.read_csv("gapminder.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys() #since dataframes are stored as dictionaries, this will work
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df["country"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1704 entries, 0 to 1703
# Series name: country
# Non-Null Count  Dtype
# --------------  -----
# 1704 non-null   object
# dtypes: object(1)
# memory usage: 13.4+ KB

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %% [markdown]
# <h3> Creating a dataframe from scratch </h3>

# %%
pd.DataFrame([["Afghanistan", 1952, 8425333, "Asia", 28.801, 779.445314], 
              ["Afghanistan", 1957, 9240934, "Asia", 30.332, 820.853030], 
              ["Afghanistan", 1962, 10267083, "Asia", 31.99, 853.100710]],
              columns = ["country", "year", "population", "continent", "life_exp", "gdp_cap"])
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.990  853.100710

# %%
pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"]) #Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:737, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     729         mgr = arrays_to_mgr(
#     730             arrays,
#     731             columns,
#    (...)
#     734             typ=manager,
#     735         )
#     736     else:
# --> 737         mgr = ndarray_to_mgr(
#     738             data,
#     739             index,
#     740             columns,
#     741             dtype=dtype,
#     742             copy=copy,
#     743             typ=manager,
#     744         )
#     745 else:
#     746     mgr = dict_to_mgr(
#     747         {},
#     748         index,
#    (...)
#     751         typ=manager,
#     752     )
#
# ...

# %%
pd.DataFrame([[1, "Ram", "IT"]], columns = ["emp_id", "name", "dept"]) #No Error
# Out:
#    emp_id name dept
# 0       1  Ram   IT

# %%
pd.DataFrame({'Name': ['Tom', 'nick', 'krish', 'jack'],
        'Age': [20, 21, 19, 18]}) #dictionary
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %% [markdown]
# <h3> CRUD Operations </h3>

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
len(df["country"].unique())
# Out:
# 142

# %%
df["country"].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df.rename({"gdp_cap":"gdp_per_cap"}, axis = 1, inplace = True) 
#without inplace, it willl just create shallow copy
df
# Out:
#           country  year  population continent  life_exp  gdp_per_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...   ...         ...       ...       ...          ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351   706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377   693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298
#
# [1704 rows x 6 columns]

# %%
# https://stackoverflow.com/questions/13842088/set-value-for-particular-cell-in-pandas-dataframe-using-index
df.at[0, "continent"] = "Temp"
df
# Out:
#           country  year  population  life_exp  gdp_per_cap continent       gdp
# 0     Afghanistan  1952     8425333    28.801   779.445314      Temp  6.567086
# 1     Afghanistan  1957     9240934    30.332   820.853030      Asia  7.585449
# 2     Afghanistan  1962    10267083    31.997   853.100710      Asia  8.758856
# 3     Afghanistan  1967    11537966    34.020   836.197138      Asia  9.648014
# 4     Afghanistan  1972    13079460    36.088   739.981106      Asia  9.678553
# ...           ...   ...         ...       ...          ...       ...       ...
# 1699     Zimbabwe  1987     9216418    62.351   706.157306    Africa  6.508241
# 1700     Zimbabwe  1992    10704340    60.377   693.420786    Africa  7.422612
# 1701     Zimbabwe  1997    11404948    46.809   792.449960    Africa  9.037851
# 1702     Zimbabwe  2002    11926563    39.989   672.038623    Africa  8.015111
# 1703     Zimbabwe  2007    12311143    43.487   469.709298    Africa  5.782658
#
# [1704 rows x 7 columns]

# %% [markdown]
# <b> Deleting columns and rows </b><br>
# [Delete Pandas Column with no name](https://stackoverflow.com/questions/39399712/delete-pandas-column-with-no-name) <br>
# [Delete rows based on condition](https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression)

# %%
continent_list = df["continent"]
print(continent_list)
print(df.drop("continent", axis = 1, inplace = False)) #doesn't actually drop the columns
# Out:
# 0         Asia
# 1         Asia
# 2         Asia
# 3         Asia
# 4         Asia
#          ...
# 1699    Africa
# 1700    Africa
# 1701    Africa
# 1702    Africa
# 1703    Africa
# Name: continent, Length: 1704, dtype: object
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
ind = np.where(df[["country"]] == "Afghanistan")[0]
df.drop(ind, inplace=False)
# Out:
#        country  year  population  life_exp  gdp_per_cap
# 12     Albania  1952     1282697    55.230  1601.056136
# 13     Albania  1957     1476505    59.280  1942.284244
# 14     Albania  1962     1728137    64.820  2312.888958
# 15     Albania  1967     1984060    66.220  2760.196931
# 16     Albania  1972     2263554    67.690  3313.422188
# ...        ...   ...         ...       ...          ...
# 1699  Zimbabwe  1987     9216418    62.351   706.157306
# 1700  Zimbabwe  1992    10704340    60.377   693.420786
# 1701  Zimbabwe  1997    11404948    46.809   792.449960
# 1702  Zimbabwe  2002    11926563    39.989   672.038623
# 1703  Zimbabwe  2007    12311143    43.487   469.709298
#
# [1692 rows x 5 columns]

# %% [markdown]
# <b>Inserting column </b>

# %%
df.drop("continent", axis = 1, inplace = True) #actually drops column
df["continent"] = continent_list
df
# Out:
#           country  year  population  life_exp     gdp_cap continent
# 0     Afghanistan  1952     8425333    28.801  779.445314      Asia
# 1     Afghanistan  1957     9240934    30.332  820.853030      Asia
# 2     Afghanistan  1962    10267083    31.997  853.100710      Asia
# 3     Afghanistan  1967    11537966    34.020  836.197138      Asia
# 4     Afghanistan  1972    13079460    36.088  739.981106      Asia
# ...           ...   ...         ...       ...         ...       ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306    Africa
# 1700     Zimbabwe  1992    10704340    60.377  693.420786    Africa
# 1701     Zimbabwe  1997    11404948    46.809  792.449960    Africa
# 1702     Zimbabwe  2002    11926563    39.989  672.038623    Africa
# 1703     Zimbabwe  2007    12311143    43.487  469.709298    Africa
#
# [1704 rows x 6 columns]

# %%
df.drop("continent", axis = 1, inplace = True)
print(type(continent_list))
continent_list = continent_list.values.tolist()
print(type(continent_list))
df.insert(3, "continent", continent_list)
df
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df["gdp"] = (df["gdp_per_cap"]*df["population"])/10**9
df
# Out:
#           country  year  population continent  life_exp  gdp_per_cap       gdp
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314  6.567086
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030  7.585449
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710  8.758856
# 3     Afghanistan  1967    11537966      Asia    34.020   836.197138  9.648014
# 4     Afghanistan  1972    13079460      Asia    36.088   739.981106  9.678553
# ...           ...   ...         ...       ...       ...          ...       ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351   706.157306  6.508241
# 1700     Zimbabwe  1992    10704340    Africa    60.377   693.420786  7.422612
# 1701     Zimbabwe  1997    11404948    Africa    46.809   792.449960  9.037851
# 1702     Zimbabwe  2002    11926563    Africa    39.989   672.038623  8.015111
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298  5.782658
#
# [1704 rows x 7 columns]

# %% [markdown]
# <h3> loc and iloc </h3>
#
# IMP: [selecting rows from dataframe based on column values](https://stackoverflow.com/questions/17071871/how-do-i-select-rows-from-a-dataframe-based-on-column-values)
# <br>
# [how to return a series/dataframe from a dataframe](https://stackoverflow.com/a/58874699/14402027)

# %%
df.loc[(df["country"] == "Afghanistan") & (df["year"] == 1952)].gdp
# Out:
# 0    6.567086
# Name: gdp, dtype: float64

# %%
df.loc[:4, "country":"continent"]
# Out:
#        country  year  population  life_exp  gdp_per_cap continent
# 0  Afghanistan  1952     8425333    28.801   779.445314      Asia
# 1  Afghanistan  1957     9240934    30.332   820.853030      Asia
# 2  Afghanistan  1962    10267083    31.997   853.100710      Asia
# 3  Afghanistan  1967    11537966    34.020   836.197138      Asia
# 4  Afghanistan  1972    13079460    36.088   739.981106      Asia

# %%
df.iloc[:4,:2]
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967

# %%
max_val = df["gdp_per_cap"].max()
df.loc[df["gdp_per_cap"] == max_val, "country"].values[0]
# Out:
# 'Kuwait'

# %%
df[["country", "year"]].tail()
# Out:
#        country  year
# 1699  Zimbabwe  1987
# 1700  Zimbabwe  1992
# 1701  Zimbabwe  1997
# 1702  Zimbabwe  2002
# 1703  Zimbabwe  2007

# %% [markdown]
# <h3><b> Aggregation </h3></b>

# %%
df.sort_values(["year", "country"], ascending = [True, False])
# Out:
#                  country  year  population  life_exp   gdp_per_cap continent  \
# 1692            Zimbabwe  1952     3080907    48.451    406.884115    Africa
# 1680              Zambia  1952     2672000    42.038   1147.388831    Africa
# 1668         Yemen, Rep.  1952     4963829    32.548    781.717576      Asia
# 1656  West Bank and Gaza  1952     1030585    43.160   1515.592329      Asia
# 1644             Vietnam  1952    26246839    40.412    605.066492      Asia
# ...                  ...   ...         ...       ...           ...       ...
# 59             Argentina  2007    40301927    75.320  12779.379640  Americas
# 47                Angola  2007    12420476    42.731   4797.231267    Africa
# 35               Algeria  2007    33333216    72.301   6223.367465    Africa
# 23               Albania  2007     3600523    76.423   5937.029526    Europe
# 11           Afghanistan  2007    31889923    43.828    974.580338      Asia
#
#              gdp
# 1692    1.253572
# ...

# %%
df["gdp_per_cap"].sum()
# Out:
# 12294917.346385501

# %% [markdown]
# <h3><b> Exploratory Data analysis </h3></b>

# %%
directors = pd.read_csv("directors.csv") #without index_col
print(directors.head())
directors = pd.read_csv("directors.csv", index_col = 0)
print("\n\n", directors.head())
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male
#
#
#         director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
directors.info() #gender for some directors in not known
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2349 entries, 0 to 2348
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  2349 non-null   object
#  1   id             2349 non-null   int64
#  2   gender         1724 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 73.4+ KB

# %%
print(directors["gender"].unique())
print(directors["gender"].value_counts(dropna=False)) #doens't count nan values
# Out:
# ['Male' nan 'Female']
# Male      1574
# NaN        625
# Female     150
# Name: gender, dtype: int64

# %%
movies = pd.read_csv("movies.csv", index_col = 0) #if we remove this, another column will be added with indexes as present in csv file
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 4768
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 137.3+ KB

# %%
#checking unique directors
print("Unique Directors:", movies["director_id"].nunique())
print("Total movies:", len(movies["id"]))
# as we can see, same director has directed multiple movies
# Out:
# Unique Directors: 199
# Total movies: 1465

# %%
print("Unique Directors:", directors["id"].nunique())
#so no duplicate directors
# Out:
# Unique Directors: 2349

# %%
directors.nunique()
# Out:
# director_name    2349
# id               2349
# gender              2
# dtype: int64

# %%
movies.tail(5)
#id is not in sequence
# Out:
#          id  budget  popularity  revenue           title  vote_average  \
# 4736  48363       0           3   321952  The Last Waltz           7.9
# 4743  48370   27000          19  3151130          Clerks           7.4
# 4748  48375       0           7        0         Rampage           6.0
# 4749  48376       0           3        0         Slacker           6.4
# 4768  48395  220000          14  2040920     El Mariachi           6.6
#
#       vote_count  director_id  year month      day
# 4736          64         4809  1978   May   Monday
# 4743         755         5369  1994   Sep  Tuesday
# 4748         131         5148  2009   Aug   Friday
# 4749          77         5535  1990   Jul   Friday
# 4768         238         5097  1992   Sep   Friday

# %% [markdown]
# <h3><b> Merge (SQL Joins) </h3></b>
#
# [Merging, Joining, Concat Megathread -> All functions](https://stackoverflow.com/questions/53645882/pandas-merging-101/53645883#53645883)

# %%
data = movies.merge(directors, how='left', left_on='director_id',right_on='id') 
data.head() #id_x, id_y not needed
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
data.drop(["id_x", "id_y"], axis = 1, inplace=True)
data.head()
# Out:
#       budget  popularity     revenue  \
# 0  237000000         150  2787965087
# 1  300000000         139   961000000
# 2  245000000         107   880674609
# 3  250000000         112  1084939099
# 4  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   budget         1465 non-null   int64
#  1   popularity     1465 non-null   int64
#  2   revenue        1465 non-null   int64
#  3   title          1465 non-null   object
#  4   vote_average   1465 non-null   float64
#  5   vote_count     1465 non-null   int64
#  6   director_id    1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
data.describe() #budget of some movies is 0, which is not possible, this is an anomaly
# Out:
#              budget   popularity       revenue  vote_average    vote_count  \
# count  1.465000e+03  1465.000000  1.465000e+03   1465.000000   1465.000000
# mean   4.802295e+07    30.855973  1.432539e+08      6.368191   1146.396587
# std    4.935541e+07    34.845214  2.064918e+08      0.818033   1578.077438
# min    0.000000e+00     0.000000  0.000000e+00      3.000000      1.000000
# 25%    1.400000e+07    11.000000  1.738013e+07      5.900000    216.000000
# 50%    3.300000e+07    23.000000  7.578164e+07      6.400000    571.000000
# 75%    6.600000e+07    41.000000  1.792469e+08      6.900000   1387.000000
# max    3.800000e+08   724.000000  2.787965e+09      8.300000  13752.000000
#
#        director_id         year
# count  1465.000000  1465.000000
# mean   5040.192491  2002.615017
# std     258.059631     8.680141
# min    4762.000000  1976.000000
# 25%    4845.000000  1998.000000
# 50%    4964.000000  2004.000000
# 75%    5179.000000  2009.000000
# ...

# %%
data.describe(include=[object])   
#avatar is the first movie, thats why it shows up as " top" movie since all the titles are unique
# Out:
#          title month     day     director_name gender
# count     1465  1465    1465              1465   1341
# unique    1465    12       7               199      2
# top     Avatar   Dec  Friday  Steven Spielberg   Male
# freq         1   193     654                26   1309

# %%
data.describe(include='all')
# Out:
#               budget   popularity       revenue   title  vote_average  \
# count   1.465000e+03  1465.000000  1.465000e+03    1465   1465.000000
# unique           NaN          NaN           NaN    1465           NaN
# top              NaN          NaN           NaN  Avatar           NaN
# freq             NaN          NaN           NaN       1           NaN
# mean    4.802295e+07    30.855973  1.432539e+08     NaN      6.368191
# std     4.935541e+07    34.845214  2.064918e+08     NaN      0.818033
# min     0.000000e+00     0.000000  0.000000e+00     NaN      3.000000
# 25%     1.400000e+07    11.000000  1.738013e+07     NaN      5.900000
# 50%     3.300000e+07    23.000000  7.578164e+07     NaN      6.400000
# 75%     6.600000e+07    41.000000  1.792469e+08     NaN      6.900000
# max     3.800000e+08   724.000000  2.787965e+09     NaN      8.300000
#
#           vote_count  director_id         year month     day  \
# count    1465.000000  1465.000000  1465.000000  1465    1465
# ...

# %% [markdown]
# <h3> Querying functions (GroupBy, Apply, filter) </h3>
#
# [index of rows where column matches a certain value](https://stackoverflow.com/questions/21800169/python-pandas-get-index-of-rows-where-column-matches-certain-value) <br>
# [LEAD-LAG in Pandas -- Also present in postread](https://stackoverflow.com/questions/23664877/pandas-equivalent-of-oracle-lead-lag-function)

# %%
data.loc[(data["vote_average"] >= 7) & (data["popularity"] >= 50)].sort_values("vote_average", ascending = False)
# Out:
#          budget  popularity     revenue                              title  \
# 383    63000000         146   100853753                         Fight Club
# 1284    8000000         121   213928762                       Pulp Fiction
# 901    22000000         104   321365567                   Schindler's List
# 45    185000000         187  1004558444                    The Dark Knight
# 917    25000000          63    46836394                         GoodFellas
# ...         ...         ...         ...                                ...
# 60    250000000         108  1021103568  The Hobbit: An Unexpected Journey
# 215    90000000          57   524028679                    Sherlock Holmes
# 668    50000000          51    32017803                           Sunshine
# 1083   18000000          52    35692920                          127 Hours
# 396    65000000          65   422610419                                300
#
# ...

# %%
data["director_name"].value_counts() #gives answer automatically in descending ordeie
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %%
print(type(data.groupby("director_name")))
print(data.groupby("director_name").ngroups)
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# 199

# %%
data.groupby("director_name").groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %% [markdown]
# <b> IMP </b> <br>
# [remove index name in pandas](https://stackoverflow.com/questions/29765548/remove-index-name-in-pandas)

# %%
data.groupby("director_name")["title"].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
data.groupby("director_name").get_group("Christopher Nolan")
# Out:
#          budget  popularity     revenue                  title  vote_average  \
# 3     250000000         112  1084939099  The Dark Knight Rises           7.6
# 45    185000000         187  1004558444        The Dark Knight           8.2
# 58    165000000         724   675120017           Interstellar           8.1
# 59    160000000         167   825532764              Inception           8.1
# 74    150000000         115   374218673          Batman Begins           7.5
# 565    46000000          41   113714830               Insomnia           6.8
# 641    40000000          74   109676311           The Prestige           8.0
# 1341    9000000          60    39723096                Memento           8.1
#
#       vote_count  director_id  year month        day      director_name gender
# 3           9106         4765  2012   Jul     Monday  Christopher Nolan   Male
# 45         12002         4765  2008   Jul  Wednesday  Christopher Nolan   Male
# ...

# %%
data.groupby("director_name")["vote_average"].mean()
# Out:
# director_name
# Adam McKay                     6.466667
# Adam Shankman                  6.037500
# Alejandro González Iñárritu    7.233333
# Alex Proyas                    6.480000
# Alexander Payne                6.880000
#                                  ...
# Wes Craven                     5.950000
# Wolfgang Petersen              6.571429
# Woody Allen                    6.672222
# Zack Snyder                    6.485714
# Zhang Yimou                    6.616667
# Name: vote_average, Length: 199, dtype: float64

# %%
data.groupby("director_name")["year"].aggregate([np.min, np.max])
#finding date of first and last movie directed
# Out:
#                              amin  amax
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
data.groupby("director_name")["year"].aggregate([np.min, np.max]).reset_index()
# Out:
#                    director_name  amin  amax
# 0                     Adam McKay  2004  2015
# 1                  Adam Shankman  2001  2012
# 2    Alejandro González Iñárritu  2000  2015
# 3                    Alex Proyas  1994  2016
# 4                Alexander Payne  1999  2013
# ..                           ...   ...   ...
# 194                   Wes Craven  1984  2011
# 195            Wolfgang Petersen  1981  2006
# 196                  Woody Allen  1977  2013
# 197                  Zack Snyder  2004  2016
# 198                  Zhang Yimou  2002  2014
#
# [199 rows x 3 columns]

# %%
#filter out risky movies - movies whose budget is greater than avg. revenue of director

def risky(x):
    #print(x.shape, "\n")
    x["risky"] = (x["budget"] - x["revenue"].mean()) > 0
    return x

risky_movies = data.groupby("director_name").apply(risky)
risky_movies
# Out:
#          budget  popularity     revenue  \
# 0     237000000         150  2787965087
# 1     300000000         139   961000000
# 2     245000000         107   880674609
# 3     250000000         112  1084939099
# 4     258000000         115   890871626
# ...         ...         ...         ...
# 1460          0           3      321952
# 1461      27000          19     3151130
# 1462          0           7           0
# 1463          0           3           0
# 1464     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
#Find squikest directors --> most movies/year
aggr_data = data.groupby("director_name")[["title", "year"]].agg({"year": ["min", "max"], "title":["count"]})
aggr_data
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
aggr_data.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
aggr_data.columns = ["_".join(i) for i in aggr_data.columns]
aggr_data.reset_index(inplace=True)
aggr_data
# Out:
#                    director_name  year_min  year_max  title_count
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
# [199 rows x 4 columns]

# %%
aggr_data["years_active"] = aggr_data["year_max"] - aggr_data["year_min"]
aggr_data["movies_per_year"] = aggr_data["title_count"]/aggr_data["years_active"]
aggr_data.sort_values("movies_per_year", ascending=False)
# Out:
#         director_name  year_min  year_max  title_count  years_active  \
# 190       Tyler Perry      2006      2013            9             7
# 73    Jason Friedberg      2006      2010            5             4
# 169        Shawn Levy      2002      2014           11            12
# 158  Robert Rodriguez      1992      2014           16            22
# 1       Adam Shankman      2001      2012            8            11
# ..                ...       ...       ...          ...           ...
# 104   Lawrence Kasdan      1985      2012            5            27
# 109        Luc Besson      1985      2014            5            29
# 157    Robert Redford      1980      2010            5            30
# 170      Sidney Lumet      1976      2006            5            30
# 117     Michael Apted      1980      2010            5            30
#
#      movies_per_year
# 190         1.285714
# 73          1.250000
# 169         0.916667
# 158         0.727273
# 1           0.727273
# ...
